# %%
import pandas as pd

Microsoft_df=pd.read_csv('Microsoft_Data.csv')

Microsoft_df
# Out:
#                       MachineIdentifier   ProductName EngineVersion  \
# 0      0000028988387b115f69f31a3bf04f09  win8defender   1.1.15100.1
# 1      000007535c3f730efa9ea0b7ef1bd645  win8defender   1.1.14600.4
# 2      000007905a28d863f6d0d597892cd692  win8defender   1.1.15100.1
# 3      00000b11598a75ea8ba1beea8459149f  win8defender   1.1.15100.1
# 4      000014a5f00daa18e76b81417eeb99fc  win8defender   1.1.15100.1
# ...                                 ...           ...           ...
# 56751  01a3aaeba82aa3de04506d45fe2f8293  win8defender   1.1.15100.1
# 56752  01a3aef1a1af51ef3e4aa0a1c99bf8b6  win8defender   1.1.15100.1
# 56753  01a3af52c05b6af7d971d5f3092c3a80  win8defender   1.1.15200.1
# 56754  01a3b0c12114367eb99eaa2fac6b754c  win8defender   1.1.15100.1
# 56755  01a3b14d2c2d4f1bc85204d10713884d  win8defender   1.1.15200.1
#
#             AppVersion  AvSigVersion  IsBeta  RtpStateBitfield  \
# 0      4.18.1807.18075  1.273.1735.0       0               7.0
# ...

# %%
import pandas as pd

Microsoft_df=pd.read_csv('Microsoft_Data.csv')

Microsoft_df.shape
Microsoft_df.columns
Microsoft_df[['ProductName','AppVersion']]
# Out:
#         ProductName       AppVersion
# 0      win8defender  4.18.1807.18075
# 1      win8defender     4.13.17134.1
# 2      win8defender  4.18.1807.18075
# 3      win8defender  4.18.1807.18075
# 4      win8defender  4.18.1807.18075
# ...             ...              ...
# 56751  win8defender  4.18.1807.18075
# 56752  win8defender  4.18.1807.18075
# 56753  win8defender  4.18.1807.18075
# 56754  win8defender  4.18.1807.18075
# 56755  win8defender  4.18.1807.18075
#
# [56756 rows x 2 columns]

# %%
import pandas as pd 
import numpy as np

Microsoft_df=pd.read_csv('Microsoft_Data.csv')

Microsoft_df.shape
Microsoft_df.columns

Microsoft_df['HasDetections'].value_counts() #value_counts is only for categorical variables
Microsoft_df['OsBuild']
Microsoft_df['OsBuild']=Microsoft_df['OsBuild'].astype('object') #for converting microsoft variable into a type
Microsoft_df['OsBuild'].value_counts() #
# Out:
# 17134    24896
# 16299    15873
# 15063     5076
# 14393     4636
# 10586     2614
# 10240     1713
# 9600      1191
# 7601       624
# 17692       15
# 17738       15
# 17744       13
# 17758       11
# 17713       10
# 17741        9
# 17754        8
# 17746        8
# 17735        6
# 17755        5
# 17751        5
# 17763        4
# 7600         4
# 17760        3
# 17666        3
# 17677        2
# 17740        1
# 17733        1
# 17730        1
# 17759        1
# 17704        1
# 17747        1
# 17686        1
# 17682        1
# 17672        1
# 17661        1
# 17643        1
# 17761        1
# Name: OsBuild, dtype: int64

# %%
import pandas as pd

Microsoft_df=pd.read_csv('Microsoft_Data.csv')

Microsoft_df.shape
Microsoft_df.columns

Microsoft_df['HasDetections']
missing_values_df=pd.DataFrame({'Column_Name':Microsoft_df.columns,
                               'Missing_values':Microsoft_df.isnull().sum(),
                               'Missing_value_percentage':Microsoft_df.isnull().sum()/Microsoft_df.shape[0]*100})

missing_values_df=missing_values_df.sort_values(by='Missing_value_percentage',ascending=False)

#droping columns with  missing value percentage greater than 50


cols_to_drop=list(missing_values_df[missing_values_df['Missing_value_percentage']>50]['Column_Name'])
                                    
Microsoft_df.drop(columns=cols_to_drop,inplace=True)
                                    
Microsoft_df.columns
# Out:
# Index(['MachineIdentifier', 'ProductName', 'EngineVersion', 'AppVersion',
#        'AvSigVersion', 'IsBeta', 'RtpStateBitfield', 'IsSxsPassiveMode',
#        'AVProductStatesIdentifier', 'AVProductsInstalled', 'AVProductsEnabled',
#        'HasTpm', 'CountryIdentifier', 'CityIdentifier',
#        'OrganizationIdentifier', 'GeoNameIdentifier',
#        'LocaleEnglishNameIdentifier', 'Platform', 'Processor', 'OsVer',
#        'OsBuild', 'OsSuite', 'OsPlatformSubRelease', 'OsBuildLab',
#        'SkuEdition', 'IsProtected', 'AutoSampleOptIn', 'SMode',
#        'IeVerIdentifier', 'SmartScreen', 'Firewall', 'UacLuaenable',
#        'Census_MDC2FormFactor', 'Census_DeviceFamily',
#        'Census_OEMNameIdentifier', 'Census_OEMModelIdentifier',
#        'Census_ProcessorCoreCount', 'Census_ProcessorManufacturerIdentifier',
#        'Census_ProcessorModelIdentifier', 'Census_PrimaryDiskTotalCapacity',
#        'Census_PrimaryDiskTypeName', 'Census_SystemVolumeTotalCapacity',
# ...

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

Microsoft_df=pd.read_csv('Microsoft_Data.csv')

Microsoft_df.shape
Microsoft_df.columns

Microsoft_df['HasDetections']
missing_values_df=pd.DataFrame({'Column_Name':Microsoft_df.columns,
                               'Missing_values':Microsoft_df.isnull().sum(),
                               'Missing_value_percentage':Microsoft_df.isnull().sum()/Microsoft_df.shape[0]*100})

missing_values_df=missing_values_df.sort_values(by='Missing_value_percentage',ascending=False)

missing_values_df=missing_values_df.drop('EngineVersion')
                                    
missing_values_df.drop
# Out:
# <bound method DataFrame.drop of                                                Column_Name  Missing_values  \
# PuaMode                                            PuaMode           56737
# Census_ProcessorClass                Census_ProcessorClass           56514
# DefaultBrowsersIdentifier        DefaultBrowsersIdentifier           53983
# Census_IsFlightingInternal      Census_IsFlightingInternal           47190
# Census_InternalBatteryType      Census_InternalBatteryType           40429
# ...                                                    ...             ...
# ProductName                                    ProductName               0
# Census_HasOpticalDiskDrive      Census_HasOpticalDiskDrive               0
# Census_PowerPlatformRoleName  Census_PowerPlatformRoleName               0
# Census_OSVersion                          Census_OSVersion               0
# HasDetections                                HasDetections               0
#
# ...

# %%
# chi square test-- used to test for the corelation between two categorical variables

import scipy.stats

crosstab = pd.crosstab(Microsoft_df['OsBuild'],Microsoft_df['HasDetections']) # build the contingency table
                                        
result=scipy.stats.chi2_contingency(crosstab) #outputs the chi-square test statisctic, p-value and degree of free

result
# Out:
# (158.07149922833526,
#  1.434114178500418e-17,
#  35,
#  array([[1.99478469e+00, 2.00521531e+00],
#         [3.11186412e+02, 3.12813588e+02],
#         [5.93947142e+02, 5.97052858e+02],
#         [8.54266545e+02, 8.58733455e+02],
#         [1.30359180e+03, 1.31040820e+03],
#         [2.31195546e+03, 2.32404454e+03],
#         [2.53138177e+03, 2.54461823e+03],
#         [7.91580436e+03, 7.95719564e+03],
#         [1.24155399e+04, 1.24804601e+04],
#         [4.98696173e-01, 5.01303827e-01],
#         [4.98696173e-01, 5.01303827e-01],
#         [1.49608852e+00, 1.50391148e+00],
#         [4.98696173e-01, 5.01303827e-01],
#         [9.97392346e-01, 1.00260765e+00],
#         [4.98696173e-01, 5.01303827e-01],
#         [4.98696173e-01, 5.01303827e-01],
#         [7.48044260e+00, 7.51955740e+00],
#         [4.98696173e-01, 5.01303827e-01],
#         [4.98696173e+00, 5.01303827e+00],
#         [4.98696173e-01, 5.01303827e-01],
#         [4.98696173e-01, 5.01303827e-01],
# ...

# %%
# chi square test-- used to test for the corelation between two categorical variables

import scipy.stats  
import numpy as np

crosstab = pd.crosstab(Microsoft_df['OsBuild'],Microsoft_df['HasDetections']) # build the contingency table
                                        
result=scipy.stats.chi2_contingency(crosstab) #outputs the chi-square test statisctic, p-value and degree of free

result

print('p_value is:',result[1])
# Out:
# p_value is: 1.434114178500418e-17

# %%
import pandas as pd
import scipy.stats
Microsoft_df=pd.read_csv("Microsoft_Data.csv")
Microsoft_df.shape
Microsoft_df.columns

cat_cols=[col for col in Microsoft_df.columns
        if  Microsoft_df[col].dtype=='object']

new_list=[]
cat_cols
for col in cat_cols:
    crosstab = pd.crosstab(Microsoft_df[col],Microsoft_df['HasDetections'])
    result=scipy.stats.chi2_contingency(crosstab) 
    new_list.append(result[1])
new_list

new_df=pd.DataFrame({'Column_Name':cat_cols,
                    'p-value':new_list})
new_df
new_df=new_df.sort_values(by='p-value',ascending=False)
new_df
# Out:
#                          Column_Name        p-value
# 11                           PuaMode   1.000000e+00
# 1                        ProductName   6.701547e-01
# 7                              OsVer   5.191060e-01
# 0                  MachineIdentifier   4.980265e-01
# 29                 Census_FlightRing   2.174158e-01
# 15             Census_ProcessorClass   7.595760e-02
# 5                           Platform   1.531325e-02
# 14               Census_DeviceFamily   2.054026e-03
# 19        Census_InternalBatteryType   6.154540e-04
# 27           Census_GenuineStateName   1.883395e-05
# 10                        SkuEdition   3.911500e-06
# 16        Census_PrimaryDiskTypeName   2.541452e-13
# 26  Census_OSWUAutoUpdateOptionsName   1.077721e-14
# 8               OsPlatformSubRelease   2.146644e-23
# 25          Census_OSInstallTypeName   1.018901e-23
# 28          Census_ActivationChannel   5.747724e-25
# 4                       AvSigVersion   6.692324e-30
# ...

# %%
sampled_means= [] #creating a list to store thr sampled means

#for 1000 times,
for i in range(0,10000):
    #take a randam sample of rows from the population,take th mean of those rows,append to sampled_means
    sampled_means.append(population['numbers'].sample(n=1000).mean())
    
#plot a histogram of sampled_mean
#it is clearly normally distribution and  centered around 5000
pd.Series(sampled_means).hist(bins=100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-7f0cda079a87> in <module>
#       4 for i in range(0,10000):
#       5     #take a randam sample of rows from the population,take th mean of those rows,append to sampled_means
# ----> 6     sampled_means.append(population['numbers'].sample(n=1000).mean())
#       7
#       8 #plot a histogram of sampled_mean
#
# NameError: name 'population' is not defined

# %%
for col in Microsoft_df.columns:
    if col!='Census_SystemVolumeTotalCapacity':
        Microsoft_df[col]=Microsoft_df[col].astype(object)

# %%
for col in Microsoft_df.columns:
    if Microsoft_df[col]!=nunique():

# %%
import pandas as pd
import numpy as np

Microsoft_df=pd.read_csv('Microsoft_Data.csv')
y=Microsoft_df['HasDetections']

Microsoft_df.drop(columns='HasDetections',inplace=True)

Microsoft_df
# Out:
#                       MachineIdentifier   ProductName EngineVersion  \
# 0      0000028988387b115f69f31a3bf04f09  win8defender   1.1.15100.1
# 1      000007535c3f730efa9ea0b7ef1bd645  win8defender   1.1.14600.4
# 2      000007905a28d863f6d0d597892cd692  win8defender   1.1.15100.1
# 3      00000b11598a75ea8ba1beea8459149f  win8defender   1.1.15100.1
# 4      000014a5f00daa18e76b81417eeb99fc  win8defender   1.1.15100.1
# ...                                 ...           ...           ...
# 56751  01a3aaeba82aa3de04506d45fe2f8293  win8defender   1.1.15100.1
# 56752  01a3aef1a1af51ef3e4aa0a1c99bf8b6  win8defender   1.1.15100.1
# 56753  01a3af52c05b6af7d971d5f3092c3a80  win8defender   1.1.15200.1
# 56754  01a3b0c12114367eb99eaa2fac6b754c  win8defender   1.1.15100.1
# 56755  01a3b14d2c2d4f1bc85204d10713884d  win8defender   1.1.15200.1
#
#             AppVersion  AvSigVersion  IsBeta  RtpStateBitfield  \
# 0      4.18.1807.18075  1.273.1735.0       0               7.0
# ...

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(Microsoft_df,y,test_size=0.3,random_state=43)

#filtering missing values

for col in x_train.columns:
    if x_train[col].dtype=='object':
        x_train[col]=x_train[col].fillna(x_train[col].mode()[0]).astype(object)
        x_test[col]=x_test[col].fillna(x_train[col].mode()[0]).astype(object)
    else:
        x_train[col]=x_train[col].fillna(x_train[col].mean())
        x_test[col]=x_test[col].fillna(x_train[col].mean())
x_train.dtypes
# Out:
# MachineIdentifier                           object
# ProductName                                 object
# EngineVersion                               object
# AppVersion                                  object
# AvSigVersion                                object
#                                             ...
# Census_IsTouchEnabled                        int64
# Census_IsPenCapable                          int64
# Census_IsAlwaysOnAlwaysConnectedCapable    float64
# Wdft_IsGamer                               float64
# Wdft_RegionIdentifier                      float64
# Length: 82, dtype: object

# %%
from sklearn.preprocessing import MinMaxScaler



min_max=MinMaxScaler()

for col in x_train.columns:
    if(x_train[col].dtype!=object):
        x_train[col]=min_max.fit_transform(x_train[[col]])
        x_test[col]=min_max.fit_transform(x_test[[col]])


x_test
#y_test
# Out:
#                       MachineIdentifier   ProductName EngineVersion  \
# 13598  006482d85deb6c4653176b3575f72767  win8defender   1.1.14901.4
# 33292  00f6438f92a9d249aab6d072fa745592  win8defender   1.1.15200.1
# 5740   002a2323c99c20df6f07fb851bf573b4  win8defender   1.1.15200.1
# 9953   004a5c3c7de2750e2816f3ce1a3bba9b  win8defender   1.1.15200.1
# 33662  00f9579126de5b04fbc6b7065e162fc9  win8defender   1.1.15100.1
# ...                                 ...           ...           ...
# 33037  00f464205028956075f315f508503be5  win8defender   1.1.15100.1
# 47967  0163343c620340db577e6904143fa1fe  win8defender   1.1.15100.1
# 19042  008d0cfeb6348cb7aacd608191cec2ee  win8defender   1.1.15200.1
# 40085  012987959abf952a9b5106081b3544e8  win8defender   1.1.15100.1
# 20184  00951125ba6dc0f2be10874ce0c66a5c  win8defender   1.1.15100.1
#
#              AppVersion  AvSigVersion  IsBeta  RtpStateBitfield  \
# 13598  4.16.17656.18052  1.269.1235.0     0.0          0.875000
# ...

# %%
from sklearn.preprocessing import LabelEncoder
import numpy as np


class LabelEncoderExt(object):
    def __init__(self):
        """
        It differs from LabelEncoder by handling new classes and providing a value for it [Unknown]
        Unknown will be added in fit and transform will take care of new item. It gives unknown class id
        """
        self.label_encoder = LabelEncoder()
        # self.classes_ = self.label_encoder.classes_

    def fit(self, data_list):
        """
        This will fit the encoder for all the unique values and introduce unknown value
        :param data_list: A list of string
        :return: self
        """
        self.label_encoder = self.label_encoder.fit(list(data_list) + ['Unknown'])
        self.classes_ = self.label_encoder.classes_

        return self

    def transform(self, data_list):
        """
        This will transform the data_list to id list where the new values get assigned to Unknown class
        :param data_list:
        :return:
        """
        new_data_list = list(data_list)
        for unique_item in np.unique(data_list):
            if unique_item not in self.label_encoder.classes_:
                new_data_list = ['Unknown' if x==unique_item else x for x in new_data_list]

        return self.label_encoder.transform(new_data_list)

# %%
from sklearn.preprocessing import LabelEncoder

le=LabelEncoderExt()
train_city=['Hyderabad','Banglore','Banglore','Pune','Hyderabad','Agra','jaipur']
test_city=['Pune','Hyderabad','Banglore','Jaipur','Agra']
le.fit(train_city)
le.transform(test_city)
# Out:
# array([3, 2, 1, 4, 0], dtype=int64)

# %%
from sklearn.preprocessing import LabelEncoder
import numpy as np

le=LabelEncoderExt()

for col in x_train.columns:
    if x_train[col].dtype=='object':
        le.fit(x_train[col])
        x_train[col]=le.transform(x_train[col])
        x_test[col]=le.transform(x_test[col])
x_train
# Out:
#        MachineIdentifier  ProductName  EngineVersion  AppVersion  \
# 55739              39026            2             33          63
# 29687              20744            2             32          36
# 5595                3878            2             33          36
# 16600              11619            2             15          16
# 12045               8397            2             33          36
# ...                  ...          ...            ...         ...
# 18448              12930            2             33          36
# 40753              28499            2             33          16
# 51455              35961            2             32          36
# 19776              13856            2             33          36
# 14148               9887            2             33          36
#
#        AvSigVersion  IsBeta  RtpStateBitfield  IsSxsPassiveMode  \
# 55739          2395     0.0             0.875               0.0
# ...

# %%
from sklearn.linear_model import LogisticRegression

logreg=LogisticRegression()
logreg.fit(x_train,y_train)
y_pred=logreg.predict(x_test)
y_pred
# Out:
# array([0, 1, 0, ..., 1, 1, 0], dtype=int64)

# %%
comparisons_df=pd.DataFrame({'Actuals':y_test,'Predictions':y_pred})

from sklearn.metrics import confusion_matrix,precision_score,recall_score,f1_score,roc_curve,roc_auc_score

confusion_matrix(y_test,y_pred)

recall_score(y_test,y_pred)
precision_score(y_test,y_pred)

f1_score(y_test,y_pred)
# Out:
# 0.6202546163550866

# %%
#AUC,ROC CURVE FOR Logistic Regression

y_pred_proba = logreg.predict_proba(x_test)[::,1]
y_pred_proba

fpr,tpr,thresholds=roc_curve(y_test,y_pred_proba)

auc=roc_auc_score(y_test,y_pred_proba)

plt.plot(fpr,tpr,label="auc="+str(auc))
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('AUC-ROC Curve')

plt.legend(loc=5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-9514cf3374da> in <module>
#       8 auc=roc_auc_score(y_test,y_pred_proba)
#       9
# ---> 10 plt.plot(fpr,tpr,label="auc="+str(auc))
#      11 plt.xlabel('False Positive Rate')
#      12 plt.ylabel('True Positive Rate')
#
# NameError: name 'plt' is not defined

# %%
scores_df=pd.DataFrame({'FPR':fpr,"Thresholds": thresholds})
scores_df
# Out:
#            FPR  Thresholds
# 0     0.000000    1.914867
# 1     0.000119    0.914867
# 2     0.000119    0.898401
# 3     0.000237    0.896747
# 4     0.000237    0.884074
# ...        ...         ...
# 7877  0.999288    0.089935
# 7878  0.999288    0.089518
# 7879  0.999881    0.074499
# 7880  0.999881    0.065843
# 7881  1.000000    0.041698
#
# [7882 rows x 2 columns]

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
X, y = load_iris(return_X_y=True)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
y_pred = gnb.fit(X_train, y_train).predict(X_test)
(X_test.shape[0], (y_test != y_pred).sum())
# Out:
# (75, 4)

# %%
# naive bayes classifier

from sklearn.naive_bayes import MultinomialNB

MultinomialNB=  MultinomialNB()
MultinomialNB.fit(x_train,y_train)
y_pred=MultinomialNB.predict(x_test)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
#AUC,ROC CURVE FOR NAIVE BAYES

y_pred_proba = MultinomialNB.predict_proba(x_test)[::,1]
y_pred_proba

fpr,tpr,thresholds=roc_curve(y_test,y_pred_proba)

auc=roc_auc_score(y_test,y_pred_proba)

plt.plot(fpr,tpr,label="auc="+str(auc))
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('AUC-ROC Curve')

plt.legend(loc=5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-58-8634d26826b7> in <module>
#       4 y_pred_proba
#       5
# ----> 6 fpr,tpr,thresholds=roc_curve(y_test,y_pred_proba)
#       7
#       8 auc=roc_auc_score(y_test,y_pred_proba)
#
# ~\deepu\lib\site-packages\sklearn\metrics\ranking.py in roc_curve(y_true, y_score, pos_label, sample_weight, drop_intermediate)
#     620     """
#     621     fps, tps, thresholds = _binary_clf_curve(
# --> 622         y_true, y_score, pos_label=pos_label, sample_weight=sample_weight)
#     623
#     624     # Attempt to drop thresholds corresponding to points in between and
#
# ~\deepu\lib\site-packages\sklearn\metrics\ranking.py in _binary_clf_curve(y_true, y_score, pos_label, sample_weight)
#     394     if not (y_type == "binary" or
#     395             (y_type == "multiclass" and pos_label is not None)):
# ...
